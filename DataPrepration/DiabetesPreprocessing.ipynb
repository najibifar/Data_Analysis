# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data['Insulin'].hist(bins=30, figsize=(5, 5))
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
skines = data[data['SkinThickness'] == 0]
skines
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 762            9       89             62              0        0  22.5
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
data[data['SkinThickness'] != 0]['SkinThickness'].mean()
# Out:
# np.float64(29.153419593345657)

# %%
skin_mean = data[data['SkinThickness'] != 0]['SkinThickness'].mean()

# %%
len(data)
# Out:
# 768

# %%
data.replace({'SkinThickness' : 0}, skin_mean, inplace=True)
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72       35.00000        0  33.6
# 1              1       85             66       29.00000        0  26.6
# 2              8      183             64       29.15342        0  23.3
# 3              1       89             66       23.00000       94  28.1
# 4              0      137             40       35.00000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76       48.00000      180  32.9
# 764            2      122             70       27.00000        0  36.8
# 765            5      121             72       23.00000      112  26.2
# 766            1      126             60       29.15342        0  30.1
# 767            1       93             70       31.00000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data['SkinThickness'].hist(bins=30, figsize=(5, 5))
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      29.153420   79.799479
# std       3.369578   31.972618      19.355807       8.790942  115.244002
# min       0.000000    0.000000       0.000000       7.000000    0.000000
# 25%       1.000000   99.000000      62.000000      25.000000    0.000000
# 50%       3.000000  117.000000      72.000000      29.153420   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
test_mean = data[data['Insulin'] != 0 ]['Insulin'].mean()

# %%
data.replace({'Insulin':0}, test_mean, inplace=True)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72       35.00000  155.548223  33.6
# 1              1       85             66       29.00000  155.548223  26.6
# 2              8      183             64       29.15342  155.548223  23.3
# 3              1       89             66       23.00000   94.000000  28.1
# 4              0      137             40       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76       48.00000  180.000000  32.9
# 764            2      122             70       27.00000  155.548223  36.8
# 765            5      121             72       23.00000  112.000000  26.2
# 766            1      126             60       29.15342  155.548223  30.1
# 767            1       93             70       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6      148             72       35.00000  155.548223  33.6
# 1            1       85             66       29.00000  155.548223  26.6
# 2            8      183             64       29.15342  155.548223  23.3
# 3            1       89             66       23.00000   94.000000  28.1
# 4            0      137             40       35.00000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
