# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data['Age'].hist(bins=40)
# Out:
# <Axes: >

# %%
data['SibSp'].hist(bins=8)
# Out:
# <Axes: >

# %%
data['Pclass'].hist(bins=3)
# Out:
# <Axes: >

# %%
data['Survived'].hist(bins=2)
# Out:
# <Axes: >

# %%
sns.set_style('darkgrid')
data['Survived'].hist(bins=2)
# Out:
# <Axes: >

# %%
data['Survived'].plot(kind='hist',bins=2)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.plot.line(x='Age', y='Pclass')
# Out:
# <Axes: xlabel='Age'>

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Pclass', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age'>

# %%
data.sort_values(['Embarked']).plot.line(x='Embarked', y='Fare', figsize=(10, 8))
# Out:
# <Axes: xlabel='Embarked'>

# %%
data.plot.scatter(x='Age', y='Pclass', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
data.plot.scatter(x='Age', y='Fare', figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
data.plot.hexbin(x='Age', y='Fare', gridsize=5 , figsize=(10, 8))
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data['Age'].hist(bins=20)
# Out:
# <Axes: >

# %%
data['Age'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data['Fare'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data.hist(figsize=(10, 8))
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data.plot.box(figsize=(10, 8))
# Out:
# <Axes: >

# %%
  pd.DataFrame([1, 2, 3, 7, 9, 10, 11, 12]).plot.box()
# Out:
# <Axes: >

# %%
pd.DataFrame([1, 2, 3, 7, 9, 10, 11, 12, 25]).quantile([0.25, 0.5, 0.75])
# Out:
#          0
# 0.25   3.0
# 0.50   9.0
# 0.75  11.0
