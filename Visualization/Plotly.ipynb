# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
src_file = os.path.join('data', 'raw', 'CO2 Emissions_Canada.csv')
image_dir = ('images')

# %%
df = pd.read_csv('co2_Emissions_Canada.csv')
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
fig = px.histogram(df, x = 'Engine Size(L)')
fig.show()

# %%
fig = px.histogram(
    df,
    x = "Fuel Consumption City (L/100 km)",
    color = "Cylinders",
    labels = {"Fuel Consumption City (L/100 km)":"annual fuel cost"},
    nbins=40,
    title = "co2_Emissions_Canada"
)
fig.show()

# %%
fig = px.colors.qualitative.swatches()
fig.show()

# %%
fig = px.histogram(
    df,
    x="Fuel Consumption City (L/100 km)",
    color="Cylinders",
    labels={"Fuel Consumption City (L/100 km)": "annual fuel cost"},
    nbins=40,
    title="co2_Emissions_Canada",
    color_discrete_sequence=px.colors.qualitative.Set2,
)
fig.show()

# %%
fig = px.colors.sequential.swatches()
fig.show()
