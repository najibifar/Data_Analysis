# %%
from scipy import stats

# %%
data = stats.binom(5000, 0.2)
print(data)
# Out:
# <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000018C910AA660>

# %%
data.pmf(1000)
# Out:
# np.float64(0.014103505478012498)

# %%
data.pmf(1500)
# Out:
# np.float64(8.418098926059112e-64)

# %%
c = 0
for i in range(0, 1067):
    c += data.pmf(i)
print(c)
# Out:
# 0.9902454274113206

# %%
data.cdf(1066)
# Out:
# np.float64(0.9902454274113204)

# %%
data = stats.poisson(160)

# %%
data.cdf(1066)
# Out:
# np.float64(1.0)

# %%
data = stats.poisson(160)

# %%
data.pmf(200)
# Out:
# np.float64(0.00027541702741491487)

# %%
data.cdf(200)
# Out:
# np.float64(0.9990057242993592)

# %%
data = stats.norm(2, 1)

# %%
data.pdf(2)
# Out:
# np.float64(0.3989422804014327)

# %%
data.cdf(3.5) - data.cdf(2.5)
# Out:
# np.float64(0.2417303374571288)
