# %%
import pandas as pd

# %%
data = pd.read_csv('flights.csv')
data.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           0  2013      1    1     517.0             515        2.0
# 1           1  2013      1    1     533.0             529        4.0
# 2           2  2013      1    1     542.0             540        2.0
# 3           3  2013      1    1     544.0             545       -1.0
# 4           4  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 0     830.0             819       11.0  ...   1545   N14228    EWR  IAH
# 1     850.0             830       20.0  ...   1714   N24211    LGA  IAH
# 2     923.0             850       33.0  ...   1141   N619AA    JFK  MIA
# 3    1004.0            1022      -18.0  ...    725   N804JB    JFK  BQN
# 4     812.0             837      -25.0  ...    461   N668DN    LGA  ATL
#
#   air_time  distance  hour  minute            time_hour  \
# 0    227.0      1400     5      15  2013-01-01 05:00:00
# 1    227.0      1416     5      29  2013-01-01 05:00:00
# 2    160.0      1089     5      40  2013-01-01 05:00:00
# 3    183.0      1576     5      45  2013-01-01 05:00:00
# 4    116.0       762     6       0  2013-01-01 06:00:00
#
#                      name
# 0   United Air Lines Inc.
# 1   United Air Lines Inc.
# 2  American Airlines Inc.
# 3         JetBlue Airways
# 4    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
data['arr_delay'].mean()
# Out:
# np.float64(6.89537675731489)

# %%
from scipy import stats
stats.trim_mean(data['arr_delay'],0.1)
# Out:
# np.float64(0.9612355338465307)

# %%
data['arr_delay'].median()
# Out:
# np.float64(-5.0)

# %%
data['arr_delay'].var()
# Out:
# np.float64(1992.13072710194)

# %%
data['arr_delay'].std()
# Out:
# np.float64(44.63329169019399)

# %%
data['arr_delay'].hist(bins=20)
# Out:
# <Axes: >

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=80)
# Out:
# <Axes: >

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=200)
# Out:
# <Axes: >

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=20)
# Out:
# <Axes: >

# %%
data['arr_delay'].std()
# Out:
# np.float64(44.63329169019399)

# %%
data['arr_delay'].mean() - (3 * data['arr_delay'].std())
# Out:
# np.float64(-127.00449831326708)

# %%
data['arr_delay'].skew()
# Out:
# np.float64(3.7168174804571863)

# %%
data['arr_delay'].kurtosis()
# Out:
# np.float64(29.233043998766775)

# %%
data.corr(numeric_only=True)
# Out:
#                 Unnamed: 0  year     month       day  dep_time  \
# Unnamed: 0        1.000000   NaN  0.071779  0.087852  0.002172
# year                   NaN   NaN       NaN       NaN       NaN
# month             0.071779   NaN  1.000000  0.002942 -0.003932
# day               0.087852   NaN  0.002942  1.000000 -0.000467
# dep_time          0.002172   NaN -0.003932 -0.000467  1.000000
# sched_dep_time    0.004076   NaN -0.004573 -0.000014  0.954617
# dep_delay         0.049713   NaN -0.020057  0.000420  0.260231
# arr_time         -0.024680   NaN -0.002520 -0.005537  0.660779
# sched_arr_time   -0.013373   NaN -0.004173 -0.002403  0.784682
# arr_delay         0.018613   NaN -0.017382 -0.000319  0.232306
# flight            0.002676   NaN -0.000834 -0.001791  0.041957
# air_time         -0.032866   NaN  0.010924  0.002236 -0.014619
# distance          0.012526   NaN  0.021636  0.003041 -0.013998
# hour              0.003150   NaN -0.005227 -0.000055  0.953306
# minute            0.022619   NaN  0.015528  0.000987  0.091577
#
#                 sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# Unnamed: 0            0.004076   0.049713 -0.024680       -0.013373
# year                       NaN        NaN       NaN             NaN
# month                -0.004573  -0.020057 -0.002520       -0.004173
# day                  -0.000014   0.000420 -0.005537       -0.002403
# dep_time              0.954617   0.260231  0.660779        0.784682
# sched_dep_time        1.000000   0.198887  0.642680        0.783342
# dep_delay             0.198887   1.000000  0.028729        0.160488
# arr_time              0.642680   0.028729  1.000000        0.788997
# sched_arr_time        0.783342   0.160488  0.788997        1.000000
# arr_delay             0.173896   0.914803  0.024482        0.133261
# flight                0.036495   0.054734  0.025042        0.021594
# air_time             -0.015532  -0.022405  0.054296        0.078918
# distance             -0.017995  -0.021671  0.046991        0.068726
# hour                  0.999148   0.198226  0.642651        0.783283
# minute                0.082960   0.028441  0.040969        0.050321
#
#                 arr_delay    flight  air_time  distance      hour    minute
# Unnamed: 0       0.018613  0.002676 -0.032866  0.012526  0.003150  0.022619
# year                  NaN       NaN       NaN       NaN       NaN       NaN
# month           -0.017382 -0.000834  0.010924  0.021636 -0.005227  0.015528
# day             -0.000319 -0.001791  0.002236  0.003041 -0.000055  0.000987
# dep_time         0.232306  0.041957 -0.014619 -0.013998  0.953306  0.091577
# sched_dep_time   0.173896  0.036495 -0.015532 -0.017995  0.999148  0.082960
# dep_delay        0.914803  0.054734 -0.022405 -0.021671  0.198226  0.028441
# arr_time         0.024482  0.025042  0.054296  0.046991  0.642651  0.040969
# sched_arr_time   0.133261  0.021594  0.078918  0.068726  0.783283  0.050321
# arr_delay        1.000000  0.072862 -0.035297 -0.061868  0.173456  0.021522
# flight           0.072862  1.000000 -0.472838 -0.484165  0.035838  0.018137
# air_time        -0.035297 -0.472838  1.000000  0.990650 -0.016277  0.017032
# distance        -0.061868 -0.484165  0.990650  1.000000 -0.018860  0.019780
# hour             0.173456  0.035838 -0.016277 -0.018860  1.000000  0.041768
# minute           0.021522  0.018137  0.017032  0.019780  0.041768  1.000000

# %%
data.corr(method='spearman', numeric_only=True)
# Out:
#                 Unnamed: 0  year     month       day  dep_time  \
# Unnamed: 0        1.000000   NaN  0.068423  0.087983  0.002409
# year                   NaN   NaN       NaN       NaN       NaN
# month             0.068423   NaN  1.000000  0.002923 -0.004394
# day               0.087983   NaN  0.002923  1.000000 -0.000463
# dep_time          0.002409   NaN -0.004394 -0.000463  1.000000
# sched_dep_time    0.004131   NaN -0.004647 -0.000080  0.971714
# dep_delay         0.039394   NaN -0.016497  0.006105  0.289806
# arr_time         -0.021611   NaN -0.003759 -0.004305  0.803024
# sched_arr_time   -0.011347   NaN -0.004762 -0.001632  0.877109
# arr_delay        -0.037711   NaN -0.014652 -0.000133  0.205734
# flight            0.004178   NaN  0.004478 -0.000430  0.034215
# air_time         -0.047133   NaN  0.005213  0.002645 -0.030119
# distance          0.005529   NaN  0.019678  0.004180 -0.028804
# hour              0.002773   NaN -0.005464 -0.000123  0.969437
# minute            0.022435   NaN  0.014267  0.001157  0.090737
#
#                 sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# Unnamed: 0            0.004131   0.039394 -0.021611       -0.011347
# year                       NaN        NaN       NaN             NaN
# month                -0.004647  -0.016497 -0.003759       -0.004762
# day                  -0.000080   0.006105 -0.004305       -0.001632
# dep_time              0.971714   0.289806  0.803024        0.877109
# sched_dep_time        1.000000   0.232511  0.785586        0.882137
# dep_delay             0.232511   1.000000  0.191679        0.217250
# arr_time              0.785586   0.191679  1.000000        0.870649
# sched_arr_time        0.882137   0.217250  0.870649        1.000000
# arr_delay             0.156957   0.626361  0.119658        0.122800
# flight                0.032365  -0.027184  0.010006        0.001905
# air_time             -0.029447   0.078865  0.056807        0.076897
# distance             -0.032579   0.076324  0.052827        0.072146
# hour                  0.997958   0.229805  0.784152        0.880184
# minute                0.094532   0.062636  0.055942        0.062724
#
#                 arr_delay    flight  air_time  distance      hour    minute
# Unnamed: 0      -0.037711  0.004178 -0.047133  0.005529  0.002773  0.022435
# year                  NaN       NaN       NaN       NaN       NaN       NaN
# month           -0.014652  0.004478  0.005213  0.019678 -0.005464  0.014267
# day             -0.000133 -0.000430  0.002645  0.004180 -0.000123  0.001157
# dep_time         0.205734  0.034215 -0.030119 -0.028804  0.969437  0.090737
# sched_dep_time   0.156957  0.032365 -0.029447 -0.032579  0.997958  0.094532
# dep_delay        0.626361 -0.027184  0.078865  0.076324  0.229805  0.062636
# arr_time         0.119658  0.010006  0.056807  0.052827  0.784152  0.055942
# sched_arr_time   0.122800  0.001905  0.076897  0.072146  0.880184  0.062724
# arr_delay        1.000000  0.067617 -0.023115 -0.074101  0.156247  0.022519
# flight           0.067617  1.000000 -0.478658 -0.483304  0.032071  0.004026
# air_time        -0.023115 -0.478658  1.000000  0.984445 -0.032251  0.033551
# distance        -0.074101 -0.483304  0.984445  1.000000 -0.035453  0.035296
# hour             0.156247  0.032071 -0.032251 -0.035453  1.000000  0.034153
# minute           0.022519  0.004026  0.033551  0.035296  0.034153  1.000000
